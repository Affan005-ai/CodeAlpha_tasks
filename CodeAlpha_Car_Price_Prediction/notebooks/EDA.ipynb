# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('\CodeAlpha_tasks\CodeAlpha_Car_Price_Prediction\Data\car data.csv')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\C'
# <>:1: SyntaxWarning: invalid escape sequence '\C'
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17648\627345078.py:1: SyntaxWarning: invalid escape sequence '\C'
#   df=pd.read_csv('\CodeAlpha_tasks\CodeAlpha_Car_Price_Prediction\Data\car data.csv')

# %%
df.shape
# Out:
# (301, 9)

# %%
print(df['Selling_type'].unique())
print(df['Fuel_Type'].unique())
print(df['Transmission'].unique())
print(df['Owner'].unique())
# Out:
# ['Dealer' 'Individual']
# ['Petrol' 'Diesel' 'CNG']
# ['Manual' 'Automatic']
# [0 1 3]

# %%
##check missing values
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Driven_kms       0
# Fuel_Type        0
# Selling_type     0
# Transmission     0
# Owner            0
# dtype: int64

# %%
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Driven_kms       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.642584   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
df_=df[['Year','Selling_Price','Present_Price','Driven_kms','Fuel_Type','Selling_type','Transmission','Owner']]

# %%
df_.head()
# Out:
#    Year  Selling_Price  Present_Price  Driven_kms Fuel_Type Selling_type  \
# 0  2014           3.35           5.59       27000    Petrol       Dealer
# 1  2013           4.75           9.54       43000    Diesel       Dealer
# 2  2017           7.25           9.85        6900    Petrol       Dealer
# 3  2011           2.85           4.15        5200    Petrol       Dealer
# 4  2014           4.60           6.87       42450    Diesel       Dealer
#
#   Transmission  Owner
# 0       Manual      0
# 1       Manual      0
# 2       Manual      0
# 3       Manual      0
# 4       Manual      0

# %%
df_['Current Year']=2026

# %%
df_.head()
# Out:
#    Year  Selling_Price  Present_Price  Driven_kms Fuel_Type Selling_type  \
# 0  2014           3.35           5.59       27000    Petrol       Dealer
# 1  2013           4.75           9.54       43000    Diesel       Dealer
# 2  2017           7.25           9.85        6900    Petrol       Dealer
# 3  2011           2.85           4.15        5200    Petrol       Dealer
# 4  2014           4.60           6.87       42450    Diesel       Dealer
#
#   Transmission  Owner  Current Year
# 0       Manual      0          2026
# 1       Manual      0          2026
# 2       Manual      0          2026
# 3       Manual      0          2026
# 4       Manual      0          2026

# %%
df_['num_year']=df_['Current Year']- df_['Year']

# %%
df_.head()
# Out:
#    Year  Selling_Price  Present_Price  Driven_kms Fuel_Type Selling_type  \
# 0  2014           3.35           5.59       27000    Petrol       Dealer
# 1  2013           4.75           9.54       43000    Diesel       Dealer
# 2  2017           7.25           9.85        6900    Petrol       Dealer
# 3  2011           2.85           4.15        5200    Petrol       Dealer
# 4  2014           4.60           6.87       42450    Diesel       Dealer
#
#   Transmission  Owner  Current Year  num_year
# 0       Manual      0          2026        12
# 1       Manual      0          2026        13
# 2       Manual      0          2026         9
# 3       Manual      0          2026        15
# 4       Manual      0          2026        12

# %%
df_.drop(['Year'],axis=1,inplace=True)

# %%
df_.head()
# Out:
#    Selling_Price  Present_Price  Driven_kms Fuel_Type Selling_type  \
# 0           3.35           5.59       27000    Petrol       Dealer
# 1           4.75           9.54       43000    Diesel       Dealer
# 2           7.25           9.85        6900    Petrol       Dealer
# 3           2.85           4.15        5200    Petrol       Dealer
# 4           4.60           6.87       42450    Diesel       Dealer
#
#   Transmission  Owner  Current Year  num_year
# 0       Manual      0          2026        12
# 1       Manual      0          2026        13
# 2       Manual      0          2026         9
# 3       Manual      0          2026        15
# 4       Manual      0          2026        12

# %%
final_dataset=df_.drop(['Current Year'],axis=1)

# %%
final_dataset.head()
# Out:
#    Selling_Price  Present_Price  Driven_kms Fuel_Type Selling_type  \
# 0           3.35           5.59       27000    Petrol       Dealer
# 1           4.75           9.54       43000    Diesel       Dealer
# 2           7.25           9.85        6900    Petrol       Dealer
# 3           2.85           4.15        5200    Petrol       Dealer
# 4           4.60           6.87       42450    Diesel       Dealer
#
#   Transmission  Owner  num_year
# 0       Manual      0        12
# 1       Manual      0        13
# 2       Manual      0         9
# 3       Manual      0        15
# 4       Manual      0        12

# %%
sns.pairplot(final_dataset)

# %%
plt.figure(figsize=(6,4))
sns.histplot(df["Selling_Price"], kde=True)
plt.title("Car Price Distribution")
plt.savefig("\CodeAlpha_tasks\CodeAlpha_Car_Price_Prediction\images\Car Price Distribution.jpeg")
plt.show()
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\C'
# <>:4: SyntaxWarning: invalid escape sequence '\C'
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17648\2639385434.py:4: SyntaxWarning: invalid escape sequence '\C'
#   plt.savefig("\CodeAlpha_tasks\CodeAlpha_Car_Price_Prediction\images\Car Price Distribution.jpeg")

# %%
num_features = df.select_dtypes(include=["int64","float64"]).columns

for col in num_features:
    if col != "Selling_Price":
        plt.figure(figsize=(5,3))
        sns.scatterplot(x=df[col], y=df["Selling_Price"])
        plt.title(f"{col} vs Price")
        plt.savefig("\CodeAlpha_tasks\CodeAlpha_Car_Price_Prediction\images\Car Price Distribution with year, present priceand driven kms.jpeg")
        plt.show()
# Out:
# <>:8: SyntaxWarning: invalid escape sequence '\C'
# <>:8: SyntaxWarning: invalid escape sequence '\C'
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17648\2978764910.py:8: SyntaxWarning: invalid escape sequence '\C'
#   plt.savefig("\CodeAlpha_tasks\CodeAlpha_Car_Price_Prediction\images\Car Price Distribution with year, present priceand driven kms.jpeg")

# %%
cat_features = df.select_dtypes(include=["object"]).columns

for col in cat_features:
    plt.figure(figsize=(20,6))
    sns.boxplot(x=df[col], y=df["Selling_Price"])
    plt.xticks(rotation=45)
    plt.title(f"{col} vs Price")
    plt.show()

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.title("Feature Correlation")
plt.savefig("\CodeAlpha_tasks\CodeAlpha_Car_Price_Prediction\images\Correlation Heatmap.jpeg")
plt.show()
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\C'
# <>:4: SyntaxWarning: invalid escape sequence '\C'
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17648\3642075734.py:4: SyntaxWarning: invalid escape sequence '\C'
#   plt.savefig("\CodeAlpha_tasks\CodeAlpha_Car_Price_Prediction\images\Correlation Heatmap.jpeg")

# %% [markdown]
# Engine power and mileage strongly affect price
#
# Brand/category impacts pricing significantly
#
# Linear + tree models are suitable
